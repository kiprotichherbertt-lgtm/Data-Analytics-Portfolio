# %% [markdown]
# <a href="https://colab.research.google.com/github/kiprotichherbertt-lgtm/Data-Analytics-Portfolio/blob/main/SQL_Practice_Herbert_Week0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd

# Create in-memory database
conn = sqlite3.connect(':memory:')

# Create a sample table
data = {'Patient_ID': [1,2,3],
        'Diagnosis': ['Flu', 'Asthma', 'Pneumonia'],
        'Age': [23, 45, 36]}

df = pd.DataFrame(data)
df.to_sql('patients', conn, index=False, if_exists='replace')

# Query the data
query = "SELECT * FROM patients"
pd.read_sql(query, conn)
# Out:
#    Patient_ID  Diagnosis  Age
# 0           1        Flu   23
# 1           2     Asthma   45
# 2           3  Pneumonia   36
